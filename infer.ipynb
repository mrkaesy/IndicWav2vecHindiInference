# %%
import sys
sys.path.append('code')
import numpy as np


import base64
encode_string = base64.b64encode(open("1.mp3", "rb").read()).decode()
print(encode_string)
# inp = w2l_decoder.get_data(encode_string,"cuda")
# Out:
# ...

# %%
from w2l_decoder import  infer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from w2l_decoder import  infer
#
# ImportError: cannot import name 'infer' from 'w2l_decoder' (/mnt/External/8TBHDD/Keyur/IndicWav2vecHindiInference/code/w2l_decoder.py)

# %%
infer(encode_string,'/mnt/External/8TBHDD/Keyur/IndicWav2vecHindiInference/code/config.yaml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 infer(encode_string,'/mnt/External/8TBHDD/Keyur/IndicWav2vecHindiInference/code/config.yaml')
#
# NameError: name 'infer' is not defined
